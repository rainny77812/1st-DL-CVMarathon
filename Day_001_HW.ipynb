# %% [markdown]
# # [作業一]

# %%
import numpy as np
import matplotlib.pyplot as plt

def mean_absolute_error(y, yp):

    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 260.553
# The Mean absolute error is 13.611

# %% [markdown]
# # [作業二]
#
# ### 我在Kaggle, Dataset中，選擇的資料為「Global Significant Earthquake Database from 2150BC」
#
# ### 1. 在全球強烈的地震發生時，必然帶有一定程度的生命及經濟損失，要是能夠預測下次強震的發生時間與強度，對人類在生存方面而言將有一定程度的貢獻。
# ### 2. 資料由National Oceanic and Atmospheric Administration, U.S.所蒐集提供。
# ### 3. 資料型態為.csv檔案，為含有數值(發生年分、規模等等)與字串(發生地等等)的表格。
# ### 4. 就預測今年地震發生是否會發生，應為一個二元分類問題，可使用的評估標準為Accuracy。發生的規模為何，應為一個回歸問題，可使用的評估標準為MSE。

# %% [markdown]
# # [作業三]
#
# ### 1. 在每日固定數量的車數，提升業績將其定義為，減少載客時的行車時間。假設載客市場為供不應求的狀態下，只要能夠找出花費最少時間的路徑，使用越短的時間完成載客，就能使業績提升。
# ### 2. 城市內各路口在不同時段內的紅綠燈秒數、城市內各條路不同時段內的行駛最高時速、城市內各條路不同時段內的車流量、天氣情況(雨天使得行駛速度下降)、氣溫(高於或低於某定值時，行駛的車輛增加)等等。
# ### 3. 多為數值型態
# ### 4. 預測出各條路的行駛時間，應為一回歸問題，可使用的評估標準為MSE。實際應用上為已知起點終點，將不同路線內的行駛時間加總比較取最小值。
